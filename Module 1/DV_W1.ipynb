# %%
# Hello World

# %%
# !pip install numpy scipy matplotlib seaborn pandas altair vega_datasets sklearn bokeh datashader holoviews wordcloud spacy
# Out:
# Requirement already satisfied: numpy in /Applications/miniconda3/lib/python3.9/site-packages (1.24.3)
# Collecting scipy
#   Downloading scipy-1.11.2-cp39-cp39-macosx_12_0_arm64.whl (29.6 MB)
#      |████████████████████████████████| 29.6 MB 3.2 MB/s eta 0:00:01
# Collecting matplotlib
#   Downloading matplotlib-3.7.2-cp39-cp39-macosx_11_0_arm64.whl (7.3 MB)
#      |████████████████████████████████| 7.3 MB 3.1 MB/s eta 0:00:01
# Collecting seaborn
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      |████████████████████████████████| 293 kB 2.5 MB/s eta 0:00:01
# Requirement already satisfied: pandas in /Applications/miniconda3/lib/python3.9/site-packages (2.0.2)
# Collecting altair
#   Downloading altair-5.0.1-py3-none-any.whl (471 kB)
#      |████████████████████████████████| 471 kB 3.9 MB/s eta 0:00:01
# Collecting vega_datasets
#   Downloading vega_datasets-0.9.0-py3-none-any.whl (210 kB)
#      |████████████████████████████████| 210 kB 2.7 MB/s eta 0:00:01
# Collecting sklearn
#   Downloading sklearn-0.0.post7.tar.gz (3.6 kB)
# Collecting bokeh
#   Downloading bokeh-3.2.2-py3-none-any.whl (7.8 MB)
#      |████████████████████████████████| 7.8 MB 1.8 MB/s eta 0:00:01
# Collecting datashader
#   Downloading datashader-0.15.2-py2.py3-none-any.whl (18.3 MB)
#      |████████████████████████████████| 18.3 MB 549 kB/s eta 0:00:01
# Collecting holoviews
#   Downloading holoviews-1.17.1-py2.py3-none-any.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 2.9 MB/s eta 0:00:01
# Collecting wordcloud
#   Downloading wordcloud-1.9.2.tar.gz (222 kB)
#      |████████████████████████████████| 222 kB 3.2 MB/s eta 0:00:01
# Collecting spacy
#   Downloading spacy-3.6.1-cp39-cp39-macosx_11_0_arm64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 222 kB/s eta 0:00:01
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Applications/miniconda3/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.5-cp39-cp39-macosx_11_0_arm64.whl (66 kB)
#      |████████████████████████████████| 66 kB 12.5 MB/s eta 0:00:01
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.1.0-cp39-cp39-macosx_11_0_arm64.whl (229 kB)
#      |████████████████████████████████| 229 kB 4.6 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7 in /Applications/miniconda3/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Collecting pillow>=6.2.0
#   Downloading Pillow-10.0.0-cp39-cp39-macosx_11_0_arm64.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 9.5 MB/s eta 0:00:011
# Requirement already satisfied: packaging>=20.0 in /Applications/miniconda3/lib/python3.9/site-packages (from matplotlib) (21.3)
# Collecting importlib-resources>=3.2.0
#   Downloading importlib_resources-6.0.1-py3-none-any.whl (34 kB)
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.42.1-cp39-cp39-macosx_10_9_universal2.whl (2.7 MB)
#      |████████████████████████████████| 2.7 MB 8.2 MB/s eta 0:00:01
# Requirement already satisfied: pytz>=2020.1 in /Applications/miniconda3/lib/python3.9/site-packages (from pandas) (2022.1)
# Requirement already satisfied: tzdata>=2022.1 in /Applications/miniconda3/lib/python3.9/site-packages (from pandas) (2023.3)
# Requirement already satisfied: typing-extensions>=4.0.1 in /Applications/miniconda3/lib/python3.9/site-packages (from altair) (4.3.0)
# Requirement already satisfied: toolz in /Applications/miniconda3/lib/python3.9/site-packages (from altair) (0.12.0)
# Requirement already satisfied: jinja2 in /Applications/miniconda3/lib/python3.9/site-packages (from altair) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /Applications/miniconda3/lib/python3.9/site-packages (from altair) (4.16.0)
# Collecting PyYAML>=3.10
#   Downloading PyYAML-6.0.1-cp39-cp39-macosx_11_0_arm64.whl (174 kB)
#      |████████████████████████████████| 174 kB 4.2 MB/s eta 0:00:01
# Collecting xyzservices>=2021.09.1
#   Downloading xyzservices-2023.7.0-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 11.7 MB/s eta 0:00:01
# Requirement already satisfied: tornado>=5.1 in /Applications/miniconda3/lib/python3.9/site-packages (from bokeh) (6.2)
# Collecting xarray
#   Downloading xarray-2023.8.0-py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 1.8 MB/s eta 0:00:01
# Collecting pyct
#   Downloading pyct-0.5.0-py2.py3-none-any.whl (15 kB)
# Collecting param
#   Downloading param-1.13.0-py2.py3-none-any.whl (87 kB)
#      |████████████████████████████████| 87 kB 3.8 MB/s eta 0:00:01
# Collecting numba
#   Downloading numba-0.57.1-cp39-cp39-macosx_11_0_arm64.whl (2.5 MB)
#      |████████████████████████████████| 2.5 MB 787 kB/s eta 0:00:01
# Collecting colorcet
#   Downloading colorcet-3.0.1-py2.py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 949 kB/s eta 0:00:01
# Collecting datashape
#   Downloading datashape-0.5.2.tar.gz (76 kB)
#      |████████████████████████████████| 76 kB 2.4 MB/s eta 0:00:011
# Collecting dask
#   Downloading dask-2023.8.1-py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 11.2 MB/s eta 0:00:01
# Requirement already satisfied: requests in /Applications/miniconda3/lib/python3.9/site-packages (from datashader) (2.27.1)
# Collecting pyviz-comms>=0.7.4
#   Downloading pyviz_comms-3.0.0-py3-none-any.whl (82 kB)
#      |████████████████████████████████| 82 kB 645 kB/s eta 0:00:011
# Collecting panel>=0.13.1
#   Downloading panel-1.2.1-py2.py3-none-any.whl (20.0 MB)
#      |████████████████████████████████| 20.0 MB 1.5 MB/s eta 0:00:01
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.4.7-cp39-cp39-macosx_11_0_arm64.whl (491 kB)
#      |████████████████████████████████| 491 kB 680 kB/s eta 0:00:01
# Requirement already satisfied: setuptools in /Applications/miniconda3/lib/python3.9/site-packages (from spacy) (61.2.0)
# Collecting typer<0.10.0,>=0.3.0
#   Downloading typer-0.9.0-py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 461 kB/s eta 0:00:01
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Applications/miniconda3/lib/python3.9/site-packages (from spacy) (4.64.0)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.8-cp39-cp39-macosx_11_0_arm64.whl (101 kB)
#      |████████████████████████████████| 101 kB 458 kB/s eta 0:00:01
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 2.5 MB/s eta 0:00:01
# Collecting spacy-legacy<3.1.0,>=3.0.11
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting pathy>=0.10.0
#   Downloading pathy-0.10.2-py3-none-any.whl (48 kB)
#      |████████████████████████████████| 48 kB 9.4 MB/s  eta 0:00:01
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.7-cp39-cp39-macosx_11_0_arm64.whl (31 kB)
# Collecting wasabi<1.2.0,>=0.9.1
#   Downloading wasabi-1.1.2-py3-none-any.whl (27 kB)
# Collecting thinc<8.2.0,>=8.1.8
#   Downloading thinc-8.1.12-cp39-cp39-macosx_11_0_arm64.whl (790 kB)
#      |████████████████████████████████| 790 kB 25.0 MB/s eta 0:00:01
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4
#   Downloading pydantic-2.3.0-py3-none-any.whl (374 kB)
#      |████████████████████████████████| 374 kB 4.5 MB/s eta 0:00:01
# Collecting smart-open<7.0.0,>=5.2.1
#   Downloading smart_open-6.3.0-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 4.4 MB/s eta 0:00:011
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.9-cp39-cp39-macosx_11_0_arm64.whl (19 kB)
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.9-py3-none-any.whl (17 kB)
# Requirement already satisfied: zipp>=3.1.0 in /Applications/miniconda3/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Applications/miniconda3/lib/python3.9/site-packages (from jinja2->altair) (2.1.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Applications/miniconda3/lib/python3.9/site-packages (from jsonschema>=3.0->altair) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /Applications/miniconda3/lib/python3.9/site-packages (from jsonschema>=3.0->altair) (22.1.0)
# Collecting markdown-it-py
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      |████████████████████████████████| 87 kB 14.1 MB/s eta 0:00:01
# Collecting markdown
#   Downloading Markdown-3.4.4-py3-none-any.whl (94 kB)
#      |████████████████████████████████| 94 kB 888 kB/s eta 0:00:01
# Collecting linkify-it-py
#   Downloading linkify_it_py-2.0.2-py3-none-any.whl (19 kB)
# Collecting mdit-py-plugins
#   Downloading mdit_py_plugins-0.4.0-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 2.3 MB/s eta 0:00:011
# Requirement already satisfied: bleach in /Applications/miniconda3/lib/python3.9/site-packages (from panel>=0.13.1->holoviews) (4.1.0)
# Collecting typing-extensions>=4.0.1
#   Downloading typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# Collecting pydantic-core==2.6.3
#   Downloading pydantic_core-2.6.3-cp39-cp39-macosx_11_0_arm64.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 34.1 MB/s eta 0:00:01
# Collecting annotated-types>=0.4.0
#   Downloading annotated_types-0.5.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: six>=1.5 in /Applications/miniconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /Applications/miniconda3/lib/python3.9/site-packages (from requests->datashader) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Applications/miniconda3/lib/python3.9/site-packages (from requests->datashader) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Applications/miniconda3/lib/python3.9/site-packages (from requests->datashader) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Applications/miniconda3/lib/python3.9/site-packages (from requests->datashader) (1.26.9)
# Collecting confection<1.0.0,>=0.0.1
#   Downloading confection-0.1.1-py3-none-any.whl (34 kB)
# Collecting blis<0.8.0,>=0.7.8
#   Downloading blis-0.7.10-cp39-cp39-macosx_11_0_arm64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 92.7 MB/s eta 0:00:01
# Collecting click<9.0.0,>=7.1.1
#   Downloading click-8.1.7-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 2.2 MB/s eta 0:00:011
# Requirement already satisfied: webencodings in /Applications/miniconda3/lib/python3.9/site-packages (from bleach->panel>=0.13.1->holoviews) (0.5.1)
# Collecting fsspec>=2021.09.0
#   Downloading fsspec-2023.6.0-py3-none-any.whl (163 kB)
#      |████████████████████████████████| 163 kB 4.0 MB/s eta 0:00:01
# Collecting cloudpickle>=1.5.0
#   Downloading cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Collecting importlib-metadata>=4.13.0
#   Downloading importlib_metadata-6.8.0-py3-none-any.whl (22 kB)
# Collecting partd>=1.2.0
#   Downloading partd-1.4.0-py3-none-any.whl (18 kB)
# Collecting locket
#   Downloading locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Collecting multipledispatch>=0.4.7
#   Downloading multipledispatch-1.0.0-py3-none-any.whl (12 kB)
# Collecting uc-micro-py
#   Downloading uc_micro_py-1.0.2-py3-none-any.whl (6.2 kB)
# Collecting mdurl~=0.1
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting llvmlite<0.41,>=0.40.0dev0
#   Downloading llvmlite-0.40.1-cp39-cp39-macosx_11_0_arm64.whl (28.1 MB)
#      |████████████████████████████████| 28.1 MB 3.4 MB/s eta 0:00:01
# Building wheels for collected packages: sklearn, wordcloud, datashape
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0.post7-py3-none-any.whl size=2975 sha256=a674f479f68fc96270fed7190bdfadae0d282a9b32a2cf27b122fddcf9297af8
#   Stored in directory: /Users/adityamhaske/Library/Caches/pip/wheels/f3/6d/ba/d999da6dff3d5cc6735e9855579fa236bf7c5bdbb210a873b8
#   Building wheel for wordcloud (setup.py) ... done
#   Created wheel for wordcloud: filename=wordcloud-1.9.2-cp39-cp39-macosx_11_0_arm64.whl size=153376 sha256=be5b4c94ef45adf34f906ad82475eeb52a8a8dcf3c467e3e25abd6596bde6102
#   Stored in directory: /Users/adityamhaske/Library/Caches/pip/wheels/fd/79/b1/1e0a49160de8dfb17c54736cc73759e1d26f9343b61c0d5441
#   Building wheel for datashape (setup.py) ... done
#   Created wheel for datashape: filename=datashape-0.5.2-py3-none-any.whl size=59438 sha256=b463c8df7c2a40c8aec58e7da0122a217d777ef729696768d4f12ad2295e1839
#   Stored in directory: /Users/adityamhaske/Library/Caches/pip/wheels/42/ef/d7/781cf80d4146d76b3d2ed2510113d78c2643c842cc6c22918d
# Successfully built sklearn wordcloud datashape
# Installing collected packages: typing-extensions, pydantic-core, mdurl, catalogue, annotated-types, xyzservices, uc-micro-py, srsly, PyYAML, pydantic, pillow, param, murmurhash, markdown-it-py, locket, importlib-metadata, cymem, contourpy, click, wasabi, typer, smart-open, pyviz-comms, pyct, preshed, partd, multipledispatch, mdit-py-plugins, markdown, llvmlite, linkify-it-py, kiwisolver, importlib-resources, fsspec, fonttools, cycler, confection, cloudpickle, bokeh, blis, xarray, thinc, spacy-loggers, spacy-legacy, scipy, pathy, panel, numba, matplotlib, langcodes, datashape, dask, colorcet, wordcloud, vega-datasets, spacy, sklearn, seaborn, holoviews, datashader, altair
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.3.0
#     Uninstalling typing-extensions-4.3.0:
#       Successfully uninstalled typing-extensions-4.3.0
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.11.3
#     Uninstalling importlib-metadata-4.11.3:
#       Successfully uninstalled importlib-metadata-4.11.3
# Successfully installed PyYAML-6.0.1 altair-5.0.1 annotated-types-0.5.0 blis-0.7.10 bokeh-3.2.2 catalogue-2.0.9 click-8.1.7 cloudpickle-2.2.1 colorcet-3.0.1 confection-0.1.1 contourpy-1.1.0 cycler-0.11.0 cymem-2.0.7 dask-2023.8.1 datashader-0.15.2 datashape-0.5.2 fonttools-4.42.1 fsspec-2023.6.0 holoviews-1.17.1 importlib-metadata-6.8.0 importlib-resources-6.0.1 kiwisolver-1.4.5 langcodes-3.3.0 linkify-it-py-2.0.2 llvmlite-0.40.1 locket-1.0.0 markdown-3.4.4 markdown-it-py-3.0.0 matplotlib-3.7.2 mdit-py-plugins-0.4.0 mdurl-0.1.2 multipledispatch-1.0.0 murmurhash-1.0.9 numba-0.57.1 panel-1.2.1 param-1.13.0 partd-1.4.0 pathy-0.10.2 pillow-10.0.0 preshed-3.0.8 pyct-0.5.0 pydantic-2.3.0 pydantic-core-2.6.3 pyviz-comms-3.0.0 scipy-1.11.2 seaborn-0.12.2 sklearn-0.0.post7 smart-open-6.3.0 spacy-3.6.1 spacy-legacy-3.0.12 spacy-loggers-1.0.4 srsly-2.4.7 thinc-8.1.12 typer-0.9.0 typing-extensions-4.7.1 uc-micro-py-1.0.2 vega-datasets-0.9.0 wasabi-1.1.2 wordcloud-1.9.2 xarray-2023.8.0 xyzservices-2023.7.0
